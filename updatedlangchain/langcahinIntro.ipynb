# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
# Verify that the API keys are loaded successfully (without printing the actual keys for security)
print("OpenAI API Key Loaded:", "OPENAI_API_KEY" in os.environ)
print("Google API Key Loaded:", "GOOGLE_API_KEY" in os.environ)
print("Groq API Key Loaded:", "GROQ_API_KEY" in os.environ)
# Out:
# OpenAI API Key Loaded: True
# Google API Key Loaded: True
# Groq API Key Loaded: True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
import os

key = os.getenv("OPENAI_API_KEY")

if key:
    print("✅ API key loaded")
else:
    print("❌ API key not found")
# Out:
# ✅ API key loaded

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

try:
    models = client.models.list()
    print("API key is valid!")
except Exception as e:
    print(e)
# Out:
# API key is valid!

# %%
import os

folder = r"D:\LANG\updatedlangchain"
filename = "introBotTesting.txt"

file_path = os.path.join(folder, filename)

if not os.path.exists(file_path):
    with open(file_path, "w"):
        pass
    print(f"File created: {file_path}")
else:
    pass  # Do nothing if file already exists


print("File check complete. Ready to use:", filename)
# Out:
# File created: D:/LANG/updatedlangchain\introBotTesting.txt
# File check complete. Ready to use: introBotTesting.txt

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()

# Initialize Ollama client
client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"  # Dummy key for local Ollama
)

log_file = r"D:\LANG\updatedlangchain\introBotTesting.txt"
long_memory_file = r"D:\LANG\updatedlangchain\longIntroMemory.txt"


with open(log_file, "a", encoding="utf-8") as f:
    f.write("\n")
    f.write("=" * 50 + "\n")
    f.write(f"Session Started: {datetime.now()}\n")
    f.write("=" * 50 + "\n\n")
# messages = []

# Last three and summary of all other conversation of less
def get_last_sessions(log_file):
    """
    Read and return the complete contents of the log file.
    """
    try:
        with open(log_file, "r", encoding="utf-8") as f:
            return f.read()
    except FileNotFoundError:
        return "Log file not found."

previous_memory = get_last_sessions(log_file)


def get_long_memory(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()
    except FileNotFoundError:
        return ""

long_memory = get_long_memory(long_memory_file)

# Compression of sessions history   
# make a new long term file.
    
    
# Personality
preso = """
You are a mischievous child.

Previous conversations:
{previous_memory}

Long-term memory:
{long_memory}

Personality:
- You enjoy teasing people.
- You are playful and sarcastic.
- You never become hateful or harmful.
- You always answer in a childlike manner.
""".format(previous_memory=previous_memory, long_memory=long_memory)

session_messages = []

# Conversation history
messages = [
    {
        "role": "system",
        "content": preso
    }
]

print("🤖 Chatbot with memory started! Type 'quit' to exit.\n")

while True:
    user_input = input("You: ")

    with open(log_file, "a", encoding="utf-8") as f:
        f.write(f"Shivansh: {user_input}\n")
        
    session_messages.append(f"User: {user_input}")
    
    
    if user_input.lower() == "quit":

        session_text = "\n".join(session_messages)

        summary_prompt = f"""
        Summarize this conversation in 5-10 bullet points.

        Conversation:
        {session_text}
        """

        summary_response = client.chat.completions.create(
            model="qwen2.5:latest",
            messages=[
                {
                    "role": "system",
                    "content": "You create concise memory summaries."
                },
                {
                    "role": "user",
                    "content": summary_prompt
                }
            ]
        )

        summary = summary_response.choices[0].message.content

        with open(long_memory_file, "a", encoding="utf-8") as f:
            f.write("\n")
            f.write("=" * 50 + "\n")
            f.write(f"Memory Added: {datetime.now()}\n")
            f.write("=" * 50 + "\n")
            f.write(summary)
            f.write("\n\n")

        print("🧠 Session summarized and saved.")
        break

    messages.append(
        {"role": "user", "content": user_input}
    )

    response = client.chat.completions.create(
        model="qwen2.5:latest",
        messages=messages
    )

    assistant_reply = response.choices[0].message.content
    
    messages.append(
        {"role": "assistant", "content": assistant_reply}
    )

    print("Bot:", assistant_reply)
    with open(log_file, "a", encoding="utf-8") as f:
        f.write(f"Bot: {assistant_reply}\n")
# Out:
# 🤖 Chatbot with memory started! Type 'quit' to exit.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[7], line 126
#     122     messages.append(
#     123         {"role": "user", "content": user_input}
#     124     )
#     125
# --> 126     response = client.chat.completions.create(
#     127         model="gpt-oss:120b-cloud",
#     128         messages=messages
#     129     )
#
# File d:\LANG\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...
