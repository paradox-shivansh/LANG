# %%
from langgraph.types import interrupt
from langgraph.tool import tool
@tool
def human_assisstance(query:str)->str:
    """
    This tool request from a human.
    """
    human_response = interrupt({"query": query})
    return human_response["response"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from langgraph.types import interrupt
# ----> 2 from langgraph.tool import tool
#       3 @tool
#       4 def human_assisstance(query:str)->str:
#       5     """
#
# ModuleNotFoundError: No module named 'langgraph.tool'
