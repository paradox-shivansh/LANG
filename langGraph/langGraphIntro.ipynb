# %% [markdown]
# # Lang Graph
#     1. CHAT BOT
#     2. TOOLS, MULTI TOOLS
#     3. ADDING MEMORY
#     4. HITL
#     5. STREAMING
#     6. MCP
#
#         In LangGraph:
#
#             Nodes = do work
#             Edges = decide where to go next
#             State = information shared between nodes
#
#             The state is actually the most important concept.

# %% [markdown]
# 2. What is State?
#
# Think of state as a shared notebook.
#
# Every node can:
#
# Read from the notebook
# Write to the notebook

# %% [markdown]
# <!--  -->
# ## Basic chatbot using lang graph
#     State → what information is shared.
#     Nodes → functions that do work.
#     Edges → define the flow between nodes.

# %%
from langsmith import Client
from langchain.chat_models import ChatOpenAI
from langgraph import Graph, Node

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model="qwen2.5:latest"
)
